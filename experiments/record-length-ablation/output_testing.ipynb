# %%
import torch
import matplotlib.pyplot as plt

# %%
rwrds = torch.load("./saved_rwrds_overwrite.pt")
rates = torch.load("./saved_rates_overwrite.pt")

# %%
record_length = torch.arange(1, rwrds.shape[0]+1)
iterations = torch.arange(rwrds.shape[1])

# %%
plt.plot(iterations, rwrds.t())
plt.show()

# %%
plt.plot(iterations, rates[-1, :])
plt.show()

# %%
mean_rwrds = rwrds.mean(-1)

# %%
plt.plot(record_length, mean_rwrds)
plt.show()

# %%
jumps = torch.abs(rates[:, 1:] - rates[:, :-1])
mean_jumps = jumps.mean(-1)

# %%
plt.plot(record_length, mean_jumps)
plt.show()
